# %% [markdown]
# ## Loading Data

# %%
import pandas as pd
from sklearn.cross_validation import train_test_split
from sklearn.svm import SVR

# %%
dfFinal = pd.read_csv('News_Final.csv')
dfFb_Ec = pd.read_csv('Facebook_Economy.csv')
dfFb_Ms = pd.read_csv('Facebook_Microsoft.csv')
dfFb_Ob = pd.read_csv('Facebook_Obama.csv')
dfFb_Pa = pd.read_csv('Facebook_Palestine.csv')
dfGo_Pa = pd.read_csv('GooglePlus_Palestine.csv')
dfGo_Ob = pd.read_csv('GooglePlus_Obama.csv')
dfGo_Ms = pd.read_csv('GooglePlus_Microsoft.csv')
dfGo_Ec = pd.read_csv('GooglePlus_Economy.csv')
dfLd_Pa = pd.read_csv('LinkedIn_Palestine.csv')
dfLd_Ob = pd.read_csv('LinkedIn_Obama.csv')
dfLd_Ms = pd.read_csv('LinkedIn_Microsoft.csv')
dfLd_Ec = pd.read_csv('LinkedIn_Economy.csv')

# %%
dfFinal
# Out:
#          IDLink                                              Title  \
# 0       99248.0   Obama Lays Wreath at Arlington National Cemetery
# 1       10423.0        A Look at the Health of the Chinese Economy
# 2       18828.0   Nouriel Roubini: Global Economy Not Back to 2008
# 3       27788.0                          Finland GDP Expands In Q4
# 4       27789.0  Tourism, govt spending buoys Thai economy in J...
# 5       27790.0  Intellitec Solutions to Host 13th Annual Sprin...
# 6       80690.0                                Monday, 29 Feb 2016
# 7       80762.0  Obama, stars pay a musical tribute to Ray Charles
# 8       80771.0  Fire claims more than 100-year-old barn in Han...
# 9       27803.0        Microsoft's new Windows 10 ad targets Apple
# 10      27813.0  Microsoft Project Centennial seen with “univer...
# 11      27812.0  Microsoft sneaks onto Android while Android sn...
# 12      27838.0  Greek economy grows 0.1 pct q/q in fourth quarter
# ...

# %%
df = dfFinal[(dfFinal.Facebook != -1) & (dfFinal.GooglePlus != -1) & (dfFinal.LinkedIn != -1)]

# %%
df_X1 = df.iloc[:,0:7]
df_X = df_X1.drop(['PublishDate'])
df_Y = df.iloc[:,8]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-925b692fd37b> in <module>()
#       1 df_X1 = df.iloc[:,0:7]
# ----> 2 df_X = df_X1.drop(['PublishDate'])
#       3 df_Y = df.iloc[:,8]
#
# /Users/nishantrathi/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in drop(self, labels, axis, level, inplace, errors)
#    2159                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2160             else:
# -> 2161                 new_axis = axis.drop(labels, errors=errors)
#    2162             dropped = self.reindex(**{axis_name: new_axis})
#    2163             try:
#
# /Users/nishantrathi/anaconda/lib/python2.7/site-packages/pandas/core/indexes/base.pyc in drop(self, labels, errors)
#    3622             if errors != 'ignore':
#    3623                 raise ValueError('labels %s not contained in axis' %
# ...

# %%
xtrain, xtest, ytrain, ytest = train_test_split(df_X, df_Y, test_size=0.25)

# %%
clf = SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.2, gamma='auto',
    kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
clf.fit(xtrain, ytrain)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-7e932cdaaea6> in <module>()
# ----> 1 clf.fit(xtrain, ytrain)
#
# /Users/nishantrathi/anaconda/lib/python2.7/site-packages/sklearn/svm/base.pyc in fit(self, X, y, sample_weight)
#     147         self._sparse = sparse and not callable(self.kernel)
#     148
# --> 149         X, y = check_X_y(X, y, dtype=np.float64, order='C', accept_sparse='csr')
#     150         y = self._validate_targets(y)
#     151
#
# /Users/nishantrathi/anaconda/lib/python2.7/site-packages/sklearn/utils/validation.pyc in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     571     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
# ...
